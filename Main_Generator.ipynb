# %%
import os
import pandas as pd
import numpy as np
import PIL
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.models import load_model,save_model
from keras.callbacks import ModelCheckpoint
from matplotlib.patches import Rectangle
import os
from scipy.misc import imsave

import keras

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.preprocessing import image
from keras.applications import xception
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Input, Lambda
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers import BatchNormalization
from math import sqrt
from keras.callbacks import History 
import gc
from numpy.random import randint, choice
import numpy.random as rng

import keras.backend as K
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.preprocessing import image

def read_img(filepath, size):
    img = image.load_img((filepath), target_size=size)
    img = image.img_to_array(img,data_format='channels_last')
    return img

# %%
input_dim = (45,45,3)
imgSize=(45,45)

basePath = "/home/rsk/Documents/Projects/GenericModels/SiameseNetworks/Dataset"
trainPath = os.path.join(basePath,'Train')
testPath = os.path.join(basePath,'Test')

# %%
folderList = os.listdir(trainPath)

# %% [markdown]
# ### Generator Method

# %%
class Generator:
    
    def __init__(self,numCharacters):
        
        self.posSampleProb = np.repeat(1/30.0,30)
        self.posSampleList = np.repeat(1.0,30)
        
        self.negSampleNames=[]

        for x in range(len(folderList)-1):
            for y in range(x+1,len(folderList)):
                self.negSampleNames.append(str(x)+'_'+str(y))

        self.negSampleProb = np.repeat(1.0/len(self.negSampleNames),len(self.negSampleNames))
        self.negSampleList = np.repeat(1.0,len(self.negSampleNames))
        
    
    
    def updateProb(self):
    
        newPosProb = np.zeros(self.posSampleProb.shape)

        for i in range(len(self.posSampleProb)):
            newPosProb[i] =  sum(self.posSampleList) - self.posSampleList[i]
            
#             newPosProb[i] = max(0.0,1.0/len(self.posSampleProb) - newPosProb[i])
        newPosProb = newPosProb/sum(newPosProb)
        self.posSampleProb = newPosProb


        newNegProb = np.zeros(self.negSampleProb.shape)

        for i in range(len(self.negSampleProb)):
            newNegProb[i] = sum(self.negSampleList) - self.negSampleList[i]
#             newNegProb[i] = max(0.0,1.0/len(self.negSampleProb) - newNegProb[i])
        newNegProb = newNegProb/sum(newNegProb)
        self.negSampleProb = newNegProb
        
    
    def getBatch(self,batchSize):
    

        posSamples = batchSize/2 + batchSize%2
        negSamples = batchSize - posSamples

#         print(self.posSampleProb)
#         print(self.negSampleProb)
    
        #positiveSamples 
        posPairList = []
        posFolder = choice(len(folderList),p=self.posSampleProb)

        imgList = os.listdir(os.path.join(trainPath,folderList[posFolder]))

        for x in range(len(imgList)-1):
            for y in range(x+1, len(imgList)):

                img1 = read_img(os.path.join(trainPath,folderList[posFolder],imgList[x]) , imgSize)
                img2 = read_img(os.path.join(trainPath,folderList[posFolder],imgList[y]) , imgSize)


                posPairList.append(((img1,img2),1))

                if len(posPairList) == posSamples:
                    break

        self.posSampleList[posFolder] += posSamples


        #negativeSamples
        negPairList = []



        for i in range(negSamples):
            folderNo = choice(len(self.negSampleNames),p=self.negSampleProb)
            negFolder = self.negSampleNames[folderNo]

            x,y = int(negFolder.split("_")[0]),int(negFolder.split("_")[0])

            imgList1 = os.listdir(os.path.join(trainPath,folderList[x]))
            imgList2 = os.listdir(os.path.join(trainPath,folderList[y]))

            img1 = read_img(os.path.join(trainPath,folderList[x],imgList1[choice(len(imgList1))]) , imgSize)
            img2 = read_img(os.path.join(trainPath,folderList[y],imgList2[choice(len(imgList2))]) , imgSize)

            negPairList.append(((img1,img2),0))

            self.negSampleList[folderNo]+=1

            if len(negPairList) == negSamples:
                break

        self.updateProb()

        pairList = posPairList + negPairList


        inputAimgs = np.array([x[0][0] for x in pairList])
        inputBimgs = np.array([x[0][1] for x in pairList])
        target = np.array([x[1] for x in pairList])        

        return( [inputAimgs,inputBimgs], target)
    
    
    def generate(self, batch_size, s="train"):
        """a generator for batches, so model.fit_generator can be used. """
        while True:
            pairs, targets = self.getBatch(batch_size,s)
            yield (pairs, targets)

# %%
def euclidean_distance(vects):
    x, y = vects
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)


def contrastive_loss(y_true, y_pred):
    '''Contrastive loss from Hadsell-et-al.'06
    http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    '''
    margin = 1
    return K.mean(y_true * K.square(y_pred) + (1 - y_true) * K.square(K.maximum(margin - y_pred, 0)))

def compute_accuracy(predictions, labels):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    return labels[predictions.ravel() < 0.5].mean()

def W_init(shape,name=None):
    """Initialize weights as in paper"""
    values = rng.normal(loc=0,scale=1e-2,size=shape)
    return K.variable(values,name=name)
#//TODO: figure out how to initialize layer biases in keras.

def b_init(shape,name=None):
    """Initialize bias as in paper"""
    values=rng.normal(loc=0.5,scale=1e-2,size=shape)
    return K.variable(values,name=name)

# %%
baseModel = Sequential()
baseModel.add(BatchNormalization(input_shape = input_dim))
baseModel.add(Conv2D(64, (7,7),activation='relu', data_format='channels_last',kernel_initializer=W_init))
baseModel.add(MaxPooling2D())

baseModel.add(Dropout(0.3))
baseModel.add(Conv2D(128, (5,5),activation='relu',kernel_initializer=W_init, bias_initializer=b_init))
baseModel.add(Dropout(0.3))
baseModel.add(Conv2D(256, (3,3),activation='relu',kernel_initializer=W_init, bias_initializer=b_init))
baseModel.add(Flatten())
baseModel.add(Dense(1028, activation='relu'))
# baseModel.add(Dense(32, activation='relu'))


inputA = Input(shape = input_dim)
inputB = Input(shape = input_dim)

outputA = baseModel(inputA)
outputB = baseModel(inputB)

#Extracting data
# inputAimgs = np.array([x[0][0] for x in superList])
# inputBimgs = np.array([x[0][1] for x in superList])
# target = np.array([x[1] for x in superList])

# %% [markdown]
# ### Model 1

# %%
L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
L1_distance = L1_layer([outputA, outputB])
prediction = Dense(1,activation='sigmoid')(L1_distance)
siamese_net = Model(inputs=[inputA,inputB],outputs=prediction)

siamese_net.compile(loss="binary_crossentropy",optimizer='adadelta',metrics=['accuracy'])

# %%
siamese_net.fit([inputAimgs,inputBimgs], target, batch_size = 20,epochs = 10 )

# %% [markdown]
# ### Model 2

# %%
distance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([outputA,outputB])

model = Model(input=[inputA, inputB], output=distance)

model.compile(loss=contrastive_loss,optimizer='adadelta')
# Out:
# /home/rsk/.local/lib/python2.7/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("la..., inputs=[<tf.Tenso...)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model.compile(loss=contrastive_loss,optimizer='adam')

# %%
gen = Generator(30)

# %%
model.fit_generator(gen.generate(25),epochs=1,steps_per_epoch = 4)
# Out:
# Epoch 1/15
# 30/30 [==============================] - 7s 240ms/step - loss: 0.1020
# Epoch 2/15
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1081
# Epoch 3/15
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1060
# Epoch 4/15
# 30/30 [==============================] - 7s 233ms/step - loss: 0.1069
# Epoch 5/15
# 30/30 [==============================] - 7s 238ms/step - loss: 0.1043
# Epoch 6/15
# 30/30 [==============================] - 7s 238ms/step - loss: 0.1034
# Epoch 7/15
# 30/30 [==============================] - 7s 236ms/step - loss: 0.1034
# Epoch 8/15
# 30/30 [==============================] - 7s 239ms/step - loss: 0.1034
# Epoch 9/15
# 30/30 [==============================] - 8s 251ms/step - loss: 0.1034
# Epoch 10/15
# 30/30 [==============================] - 7s 238ms/step - loss: 0.1034
# Epoch 11/15
# 30/30 [==============================] - 7s 246ms/step - loss: 0.1034
# Epoch 12/15
# 30/30 [==============================] - 8s 251ms/step - loss: 0.1034
# Epoch 13/15
# 30/30 [==============================] - 7s 233ms/step - loss: 0.1034
# Epoch 14/15
# 30/30 [==============================] - 7s 246ms/step - loss: 0.1034
# Epoch 15/15
# 30/30 [==============================] - 7s 236ms/step - loss: 0.1034

# %%
gen.negSampleList
# Out:
# array([ 2.,  3.,  4.,  3.,  5.,  8.,  4.,  5.,  3.,  2.,  3.,  3.,  9.,
#         1.,  2.,  5.,  7.,  2.,  3.,  6.,  3.,  4.,  4.,  2.,  2.,  6.,
#         5.,  1.,  4.,  8.,  5.,  1.,  2.,  3.,  4.,  3.,  3.,  2.,  2.,
#         4.,  6.,  3.,  2.,  6.,  3.,  5.,  6.,  1.,  4.,  3.,  3.,  3.,
#         4.,  7.,  5.,  4.,  3.,  2.,  5.,  3.,  5.,  3.,  4.,  5.,  8.,
#         1.,  1.,  5.,  4.,  4.,  2.,  9.,  6.,  5.,  2.,  2.,  3.,  4.,
#         3.,  4.,  3.,  3.,  5.,  4.,  2.,  9.,  3.,  2.,  5.,  3.,  2.,
#         3.,  4.,  1.,  3.,  5.,  6.,  3.,  4.,  3.,  1.,  3.,  4.,  4.,
#         5.,  4.,  4.,  6.,  3.,  6.,  6.,  5.,  3.,  3.,  4.,  3.,  2.,
#         4.,  4.,  3.,  2.,  5.,  8.,  5.,  5.,  7.,  3.,  2.,  2.,  3.,
#         5.,  6.,  2.,  5.,  1.,  5.,  3.,  2.,  4.,  1.,  3.,  2.,  6.,
#         5.,  1.,  3.,  5.,  2.,  5.,  5.,  3.,  2.,  4.,  7.,  3.,  3.,
#         3.,  3.,  2.,  3.,  1.,  7.,  1.,  3.,  2.,  4.,  2.,  2.,  2.,
#         4.,  4.,  2.,  5.,  5.,  2.,  3.,  7.,  3.,  4.,  6.,  6.,  2.,
#         7.,  2.,  1., 10.,  4.,  3.,  3.,  4.,  4.,  3.,  3.,  3.,  5.,
#         5.,  3.,  3.,  3.,  8.,  1.,  3.,  3.,  9., 10.,  1.,  4.,  4.,
#         3.,  4.,  2.,  3.,  6.,  4.,  4.,  5.,  3.,  3.,  3.,  8.,  6.,
#         1.,  4.,  1.,  3.,  4.,  5.,  6.,  5.,  2.,  3.,  3.,  5.,  4.,
#         4.,  3.,  3.,  5.,  4.,  2.,  5.,  4.,  3.,  1.,  6.,  5.,  5.,
#         5.,  3.,  3.,  5.,  7.,  6.,  5.,  4.,  4.,  8.,  4.,  2.,  1.,
#         4.,  3.,  4.,  5.,  3.,  5.,  3.,  5.,  4.,  2.,  3.,  3.,  3.,
#         2.,  5.,  4.,  4.,  3.,  3.,  2.,  2.,  2.,  5.,  3.,  5.,  4.,
#         2.,  3.,  3.,  3.,  4.,  3.,  1.,  5.,  4.,  4.,  3.,  3.,  4.,
#         5.,  3.,  5.,  2.,  4.,  4.,  4.,  3.,  1.,  5.,  3.,  5.,  5.,
#         4.,  4.,  2.,  2.,  3.,  3.,  8.,  2.,  1.,  5.,  8.,  4.,  3.,
#         1.,  5.,  1.,  3.,  3.,  7.,  1.,  5.,  5.,  3.,  4.,  3.,  3.,
#         7.,  3.,  5.,  5.,  3.,  6.,  5.,  6.,  5.,  4.,  6.,  2.,  3.,
#         2.,  2.,  3.,  4.,  4.,  3.,  4.,  3.,  4.,  2.,  4.,  5.,  6.,
#         2.,  3.,  4.,  4.,  3.,  3.,  6.,  2.,  3.,  4.,  5.,  2.,  3.,
#         2.,  4.,  5.,  3.,  1.,  3.,  2.,  3.,  5.,  2.,  2.,  6.,  6.,
#         4.,  4.,  3.,  4.,  5.,  6.,  4.,  6.,  2.,  4.,  5.,  2.,  3.,
#         4.,  2.,  3.,  2.,  5.,  4.,  5.,  3.,  5.,  5.,  2.,  4.,  4.,
#         3.,  6.,  4.,  9.,  5.,  2.,  2.,  4.,  3.,  3.,  4.,  5.,  1.,
#         5.,  3.,  3.,  2.,  3.,  4.])

# %%
gen.posSampleProb
# Out:
# array([0.03283675, 0.03337848, 0.03446192, 0.03419106, 0.0339202 ,
#        0.03337848, 0.03337848, 0.03256589, 0.03229503, 0.03229503,
#        0.03364934, 0.03337848, 0.03364934, 0.03283675, 0.03364934,
#        0.03364934, 0.03337848, 0.03310762, 0.03310762, 0.03364934,
#        0.03419106, 0.03175331, 0.03256589, 0.0339202 , 0.03310762,
#        0.03446192, 0.03310762, 0.03310762, 0.03337848, 0.03364934])

# %% [markdown]
# ## Testing

# %%
def predictBest(img,label,imgSupport,model):
    
    bestPred=0.0
    bestLabel=''
    bestImg = 0
    
#     plt.subplot(211)
#     plt.imshow(img)
    
    for i in range(len(imgSupport)):
        pred = model.predict([img.reshape(1,imgSize[0],imgSize[1],3), imgSupport[i][0].reshape(1,imgSize[0],imgSize[1],3)])
#         print("label : {}  Pred : {}".format(imgSupport[i][1], pred))
        
        if pred>bestPred:
            bestPred = pred
            bestLabel = imgSupport[i][1]
            bestImg = imgSupport[i][0]
    
#     plt.subplot(212)
#     plt.imshow(bestImg)
    return(bestLabel)
    

def getSupportImgs(path):
    
    supportImg=[]
    
    os.chdir(path)
    folderList = os.listdir("./")
    
    for folder in folderList:
        os.chdir(os.path.join(path,folder))
        imgList = os.listdir("./")
        
        img = read_img(os.path.join(path,folder,choice(imgList)), imgSize)
        supportImg.append([img,folder])
        
    return(supportImg)
        

def predictBestFolder(img,label,trainPath,model,numImages = 5,printList = False,testClasses = 30):
    
    predList = []
    
    folderList = sorted(os.listdir(trainPath))[:testClasses]
    
    for folder in folderList:
        
        imgList = choice(os.listdir(os.path.join(trainPath,folder)), numImages, replace = False )
        folderPreds = []
        
        for i in range(numImages):
            folderImg = read_img(os.path.join(trainPath,folder,imgList[i]), imgSize )
            pred = model.predict([img.reshape(1,imgSize[0],imgSize[1],3), folderImg.reshape(1,imgSize[0],imgSize[1],3)])
            folderPreds.append(pred)
        
        predList.append([folder, np.mean(folderPreds)])
    
    predList = sorted(predList, key = lambda x:x[1])
    
    if printList == True:
        print(predList)
        
    return(predList[0])

def searchList(word):
    
    searchList = []
    for i in range(len(labelList)):
        if word in labelList[i]:
            searchList.append(labelList[i])
    
    return(searchList)

# %% [markdown]
# #### Accuracy on test data

# %%
## 30-way testing

os.chdir(testPath)
folderList = os.listdir("./")

correctPred = 0
testImageCount = 0

for folder in folderList:
    os.chdir(os.path.join(testPath,folder))
    imgList = os.listdir("./")
    
    for img in imgList:
        imgName = img
        testImageCount+=1
        supportImg = getSupportImgs(trainPath)
        
        img = read_img(os.path.join(testPath,folder,img), imgSize)
        bestLabel = predictBestFolder(img,folder,trainPath,model,15)[0]
        
        if bestLabel == folder:
            correctPred+=1
        acc = round(correctPred/float(testImageCount),3)
        print("Img : {} True Label : {}  Predicted Label : {} Accuracy : {}".format(imgName,folder,bestLabel,acc))
        
accuracy = correctPred/float(testImageCount)
print("Accuracy : {}".format(accuracy))
# Out:
# Img : 0047_20.png True Label : character21  Predicted Label : character21 Accuracy : 1.0
# Img : 0047_16.png True Label : character21  Predicted Label : character10 Accuracy : 0.5
# Img : 0047_17.png True Label : character21  Predicted Label : character21 Accuracy : 0.667
# Img : 0047_18.png True Label : character21  Predicted Label : character21 Accuracy : 0.75
# Img : 0047_19.png True Label : character21  Predicted Label : character21 Accuracy : 0.8
# Img : 0049_18.png True Label : character23  Predicted Label : character23 Accuracy : 0.833
# Img : 0049_17.png True Label : character23  Predicted Label : character23 Accuracy : 0.857
# Img : 0049_20.png True Label : character23  Predicted Label : character12 Accuracy : 0.75
# Img : 0049_16.png True Label : character23  Predicted Label : character23 Accuracy : 0.778
# Img : 0049_19.png True Label : character23  Predicted Label : character27 Accuracy : 0.7
# Img : 0032_18.png True Label : character06  Predicted Label : character06 Accuracy : 0.727
# Img : 0032_20.png True Label : character06  Predicted Label : character06 Accuracy : 0.75
# Img : 0032_16.png True Label : character06  Predicted Label : character16 Accuracy : 0.692
# Img : 0032_19.png True Label : character06  Predicted Label : character04 Accuracy : 0.643
# Img : 0032_17.png True Label : character06  Predicted Label : character29 Accuracy : 0.6
# Img : 0040_20.png True Label : character14  Predicted Label : character14 Accuracy : 0.625
# Img : 0040_16.png True Label : character14  Predicted Label : character29 Accuracy : 0.588
# Img : 0040_18.png True Label : character14  Predicted Label : character14 Accuracy : 0.611
# Img : 0040_17.png True Label : character14  Predicted Label : character14 Accuracy : 0.632
# Img : 0040_19.png True Label : character14  Predicted Label : character14 Accuracy : 0.65
# Img : 0034_19.png True Label : character08  Predicted Label : character14 Accuracy : 0.619
# Img : 0034_20.png True Label : character08  Predicted Label : character16 Accuracy : 0.591
# Img : 0034_17.png True Label : character08  Predicted Label : character02 Accuracy : 0.565
# Img : 0034_18.png True Label : character08  Predicted Label : character04 Accuracy : 0.542
# Img : 0034_16.png True Label : character08  Predicted Label : character08 Accuracy : 0.56
# Img : 0029_19.png True Label : character03  Predicted Label : character29 Accuracy : 0.538
# Img : 0029_16.png True Label : character03  Predicted Label : character10 Accuracy : 0.519
# Img : 0029_18.png True Label : character03  Predicted Label : character20 Accuracy : 0.5
# Img : 0029_20.png True Label : character03  Predicted Label : character29 Accuracy : 0.483
# Img : 0029_17.png True Label : character03  Predicted Label : character29 Accuracy : 0.467
# Img : 0054_20.png True Label : character28  Predicted Label : character18 Accuracy : 0.452
# Img : 0054_16.png True Label : character28  Predicted Label : character29 Accuracy : 0.438
# Img : 0054_18.png True Label : character28  Predicted Label : character08 Accuracy : 0.424
# Img : 0054_17.png True Label : character28  Predicted Label : character16 Accuracy : 0.412
# Img : 0054_19.png True Label : character28  Predicted Label : character22 Accuracy : 0.4
# Img : 0030_17.png True Label : character04  Predicted Label : character04 Accuracy : 0.417
# Img : 0030_19.png True Label : character04  Predicted Label : character04 Accuracy : 0.432
# Img : 0030_16.png True Label : character04  Predicted Label : character02 Accuracy : 0.421
# Img : 0030_18.png True Label : character04  Predicted Label : character18 Accuracy : 0.41
# Img : 0030_20.png True Label : character04  Predicted Label : character04 Accuracy : 0.425
# Img : 0038_18.png True Label : character12  Predicted Label : character12 Accuracy : 0.439
# Img : 0038_16.png True Label : character12  Predicted Label : character12 Accuracy : 0.452
# Img : 0038_20.png True Label : character12  Predicted Label : character12 Accuracy : 0.465
# Img : 0038_17.png True Label : character12  Predicted Label : character12 Accuracy : 0.477
# Img : 0038_19.png True Label : character12  Predicted Label : character12 Accuracy : 0.489
# Img : 0051_19.png True Label : character25  Predicted Label : character25 Accuracy : 0.5
# Img : 0051_16.png True Label : character25  Predicted Label : character12 Accuracy : 0.489
# Img : 0051_18.png True Label : character25  Predicted Label : character16 Accuracy : 0.479
# Img : 0051_20.png True Label : character25  Predicted Label : character06 Accuracy : 0.469
# Img : 0051_17.png True Label : character25  Predicted Label : character16 Accuracy : 0.46
# Img : 0052_17.png True Label : character26  Predicted Label : character04 Accuracy : 0.451
# Img : 0052_18.png True Label : character26  Predicted Label : character26 Accuracy : 0.462
# Img : 0052_20.png True Label : character26  Predicted Label : character26 Accuracy : 0.472
# Img : 0052_16.png True Label : character26  Predicted Label : character16 Accuracy : 0.463
# Img : 0052_19.png True Label : character26  Predicted Label : character01 Accuracy : 0.455
# Img : 0048_19.png True Label : character22  Predicted Label : character22 Accuracy : 0.464
# Img : 0048_18.png True Label : character22  Predicted Label : character04 Accuracy : 0.456
# Img : 0048_20.png True Label : character22  Predicted Label : character29 Accuracy : 0.448
# Img : 0048_17.png True Label : character22  Predicted Label : character26 Accuracy : 0.441
# Img : 0048_16.png True Label : character22  Predicted Label : character16 Accuracy : 0.433
# Img : 0039_17.png True Label : character13  Predicted Label : character22 Accuracy : 0.426
# Img : 0039_18.png True Label : character13  Predicted Label : character13 Accuracy : 0.435
# Img : 0039_19.png True Label : character13  Predicted Label : character13 Accuracy : 0.444
# Img : 0039_16.png True Label : character13  Predicted Label : character04 Accuracy : 0.438
# Img : 0039_20.png True Label : character13  Predicted Label : character13 Accuracy : 0.446
# Img : 0042_18.png True Label : character16  Predicted Label : character16 Accuracy : 0.455
# Img : 0042_17.png True Label : character16  Predicted Label : character12 Accuracy : 0.448
# Img : 0042_16.png True Label : character16  Predicted Label : character05 Accuracy : 0.441
# Img : 0042_20.png True Label : character16  Predicted Label : character14 Accuracy : 0.435
# Img : 0042_19.png True Label : character16  Predicted Label : character16 Accuracy : 0.443
# Img : 0053_18.png True Label : character27  Predicted Label : character02 Accuracy : 0.437
# Img : 0053_16.png True Label : character27  Predicted Label : character27 Accuracy : 0.444
# Img : 0053_19.png True Label : character27  Predicted Label : character12 Accuracy : 0.438
# Img : 0053_17.png True Label : character27  Predicted Label : character05 Accuracy : 0.432
# Img : 0053_20.png True Label : character27  Predicted Label : character27 Accuracy : 0.44
# Img : 0041_17.png True Label : character15  Predicted Label : character12 Accuracy : 0.434
# Img : 0041_20.png True Label : character15  Predicted Label : character04 Accuracy : 0.429
# Img : 0041_16.png True Label : character15  Predicted Label : character05 Accuracy : 0.423
# Img : 0041_19.png True Label : character15  Predicted Label : character12 Accuracy : 0.418
# Img : 0041_18.png True Label : character15  Predicted Label : character29 Accuracy : 0.412
# Img : 0046_18.png True Label : character20  Predicted Label : character29 Accuracy : 0.407
# Img : 0046_17.png True Label : character20  Predicted Label : character29 Accuracy : 0.402
# Img : 0046_20.png True Label : character20  Predicted Label : character29 Accuracy : 0.398
# Img : 0046_16.png True Label : character20  Predicted Label : character29 Accuracy : 0.393
# Img : 0046_19.png True Label : character20  Predicted Label : character10 Accuracy : 0.388
# Img : 0044_20.png True Label : character18  Predicted Label : character26 Accuracy : 0.384
# Img : 0044_17.png True Label : character18  Predicted Label : character04 Accuracy : 0.379
# Img : 0044_16.png True Label : character18  Predicted Label : character16 Accuracy : 0.375
# Img : 0044_19.png True Label : character18  Predicted Label : character04 Accuracy : 0.371
# Img : 0044_18.png True Label : character18  Predicted Label : character04 Accuracy : 0.367
# Img : 0043_18.png True Label : character17  Predicted Label : character13 Accuracy : 0.363
# Img : 0043_17.png True Label : character17  Predicted Label : character12 Accuracy : 0.359
# Img : 0043_19.png True Label : character17  Predicted Label : character12 Accuracy : 0.355
# Img : 0043_20.png True Label : character17  Predicted Label : character14 Accuracy : 0.351
# Img : 0043_16.png True Label : character17  Predicted Label : character16 Accuracy : 0.347
# Img : 0050_18.png True Label : character24  Predicted Label : character16 Accuracy : 0.344
# Img : 0050_17.png True Label : character24  Predicted Label : character04 Accuracy : 0.34
# Img : 0050_16.png True Label : character24  Predicted Label : character29 Accuracy : 0.337
# Img : 0050_19.png True Label : character24  Predicted Label : character28 Accuracy : 0.333
# Img : 0050_20.png True Label : character24  Predicted Label : character14 Accuracy : 0.33
# Img : 0033_20.png True Label : character07  Predicted Label : character16 Accuracy : 0.327
# Img : 0033_19.png True Label : character07  Predicted Label : character12 Accuracy : 0.324
# Img : 0033_17.png True Label : character07  Predicted Label : character05 Accuracy : 0.32
# Img : 0033_16.png True Label : character07  Predicted Label : character05 Accuracy : 0.317
# Img : 0033_18.png True Label : character07  Predicted Label : character05 Accuracy : 0.314
# Img : 0036_19.png True Label : character10  Predicted Label : character10 Accuracy : 0.321
# Img : 0036_17.png True Label : character10  Predicted Label : character10 Accuracy : 0.327
# Img : 0036_16.png True Label : character10  Predicted Label : character10 Accuracy : 0.333
# Img : 0036_20.png True Label : character10  Predicted Label : character10 Accuracy : 0.339
# Img : 0036_18.png True Label : character10  Predicted Label : character10 Accuracy : 0.345
# Img : 0037_19.png True Label : character11  Predicted Label : character16 Accuracy : 0.342
# Img : 0037_20.png True Label : character11  Predicted Label : character29 Accuracy : 0.339
# Img : 0037_17.png True Label : character11  Predicted Label : character08 Accuracy : 0.336
# Img : 0037_16.png True Label : character11  Predicted Label : character22 Accuracy : 0.333
# Img : 0037_18.png True Label : character11  Predicted Label : character16 Accuracy : 0.33
# Img : 0027_20.png True Label : character01  Predicted Label : character04 Accuracy : 0.328
# Img : 0027_16.png True Label : character01  Predicted Label : character10 Accuracy : 0.325
# Img : 0027_19.png True Label : character01  Predicted Label : character13 Accuracy : 0.322
# Img : 0027_18.png True Label : character01  Predicted Label : character04 Accuracy : 0.319
# Img : 0027_17.png True Label : character01  Predicted Label : character01 Accuracy : 0.325
# Img : 0035_17.png True Label : character09  Predicted Label : character13 Accuracy : 0.322
# Img : 0035_20.png True Label : character09  Predicted Label : character19 Accuracy : 0.32
# Img : 0035_19.png True Label : character09  Predicted Label : character13 Accuracy : 0.317
# Img : 0035_16.png True Label : character09  Predicted Label : character02 Accuracy : 0.315
# Img : 0035_18.png True Label : character09  Predicted Label : character13 Accuracy : 0.312
# Img : 0056_17.png True Label : character30  Predicted Label : character29 Accuracy : 0.31
# Img : 0056_20.png True Label : character30  Predicted Label : character29 Accuracy : 0.307
# Img : 0056_16.png True Label : character30  Predicted Label : character30 Accuracy : 0.313
# Img : 0056_19.png True Label : character30  Predicted Label : character19 Accuracy : 0.31
# Img : 0056_18.png True Label : character30  Predicted Label : character20 Accuracy : 0.308
# Img : 0028_20.png True Label : character02  Predicted Label : character12 Accuracy : 0.305
# Img : 0028_17.png True Label : character02  Predicted Label : character02 Accuracy : 0.311
# Img : 0028_18.png True Label : character02  Predicted Label : character23 Accuracy : 0.308
# Img : 0028_16.png True Label : character02  Predicted Label : character02 Accuracy : 0.313
# Img : 0028_19.png True Label : character02  Predicted Label : character23 Accuracy : 0.311
# Img : 0045_18.png True Label : character19  Predicted Label : character19 Accuracy : 0.316
# Img : 0045_17.png True Label : character19  Predicted Label : character19 Accuracy : 0.321
# Img : 0045_20.png True Label : character19  Predicted Label : character28 Accuracy : 0.319
# Img : 0045_16.png True Label : character19  Predicted Label : character10 Accuracy : 0.317
# Img : 0045_19.png True Label : character19  Predicted Label : character19 Accuracy : 0.321
# Img : 0055_19.png True Label : character29  Predicted Label : character29 Accuracy : 0.326
# Img : 0055_20.png True Label : character29  Predicted Label : character29 Accuracy : 0.331
# Img : 0055_16.png True Label : character29  Predicted Label : character04 Accuracy : 0.329
# Img : 0055_18.png True Label : character29  Predicted Label : character26 Accuracy : 0.326
# Img : 0055_17.png True Label : character29  Predicted Label : character29 Accuracy : 0.331
# Img : 0031_19.png True Label : character05  Predicted Label : character12 Accuracy : 0.329
# Img : 0031_20.png True Label : character05  Predicted Label : character12 Accuracy : 0.327
# Img : 0031_18.png True Label : character05  Predicted Label : character14 Accuracy : 0.324
# Img : 0031_16.png True Label : character05  Predicted Label : character12 Accuracy : 0.322
# Img : 0031_17.png True Label : character05  Predicted Label : character12 Accuracy : 0.32
# Accuracy : 0.32

# %%
accuracy = correctPred/float(testImageCount)
print("Accuracy : {}".format(accuracy))
# Out:
# Accuracy : 0.74

# %%
# 20-way testing



os.chdir(testPath)
folderList = sorted(os.listdir("./"))[:20]

correctPred = 0
testImageCount = 0

for folder in folderList:
    os.chdir(os.path.join(testPath,folder))
    imgList = os.listdir("./")
    
    for img in imgList:
        imgName = img
        testImageCount+=1
        
        img = read_img(os.path.join(testPath,folder,img), imgSize)
        bestLabel = predictBestFolder(img,folder,trainPath,model,15,testClasses=20)[0]
        
        if bestLabel == folder:
            correctPred+=1
        acc = round(correctPred/float(testImageCount),3)
        print("Img : {} True Label : {}  Predicted Label : {} Accuracy : {}".format(imgName,folder,bestLabel,acc))
        
accuracy = correctPred/float(testImageCount)
print("Accuracy : {}".format(accuracy))
# Out:
# Img : 0027_20.png True Label : character01  Predicted Label : character01 Accuracy : 1.0
# Img : 0027_16.png True Label : character01  Predicted Label : character01 Accuracy : 1.0
# Img : 0027_19.png True Label : character01  Predicted Label : character01 Accuracy : 1.0
# Img : 0027_18.png True Label : character01  Predicted Label : character01 Accuracy : 1.0
# Img : 0027_17.png True Label : character01  Predicted Label : character01 Accuracy : 1.0
# Img : 0028_20.png True Label : character02  Predicted Label : character02 Accuracy : 1.0
# Img : 0028_17.png True Label : character02  Predicted Label : character02 Accuracy : 1.0
# Img : 0028_18.png True Label : character02  Predicted Label : character02 Accuracy : 1.0
# Img : 0028_16.png True Label : character02  Predicted Label : character02 Accuracy : 1.0
# Img : 0028_19.png True Label : character02  Predicted Label : character02 Accuracy : 1.0
# Img : 0029_19.png True Label : character03  Predicted Label : character03 Accuracy : 1.0
# Img : 0029_16.png True Label : character03  Predicted Label : character03 Accuracy : 1.0
# Img : 0029_18.png True Label : character03  Predicted Label : character03 Accuracy : 1.0
# Img : 0029_20.png True Label : character03  Predicted Label : character03 Accuracy : 1.0
# Img : 0029_17.png True Label : character03  Predicted Label : character03 Accuracy : 1.0
# Img : 0030_17.png True Label : character04  Predicted Label : character04 Accuracy : 1.0
# Img : 0030_19.png True Label : character04  Predicted Label : character04 Accuracy : 1.0
# Img : 0030_16.png True Label : character04  Predicted Label : character04 Accuracy : 1.0
# Img : 0030_18.png True Label : character04  Predicted Label : character18 Accuracy : 0.947
# Img : 0030_20.png True Label : character04  Predicted Label : character04 Accuracy : 0.95
# Img : 0031_19.png True Label : character05  Predicted Label : character07 Accuracy : 0.905
# Img : 0031_20.png True Label : character05  Predicted Label : character05 Accuracy : 0.909
# Img : 0031_18.png True Label : character05  Predicted Label : character05 Accuracy : 0.913
# Img : 0031_16.png True Label : character05  Predicted Label : character05 Accuracy : 0.917
# Img : 0031_17.png True Label : character05  Predicted Label : character04 Accuracy : 0.88
# Img : 0032_18.png True Label : character06  Predicted Label : character20 Accuracy : 0.846
# Img : 0032_20.png True Label : character06  Predicted Label : character06 Accuracy : 0.852
# Img : 0032_16.png True Label : character06  Predicted Label : character06 Accuracy : 0.857
# Img : 0032_19.png True Label : character06  Predicted Label : character03 Accuracy : 0.828
# Img : 0032_17.png True Label : character06  Predicted Label : character18 Accuracy : 0.8
# Img : 0033_20.png True Label : character07  Predicted Label : character07 Accuracy : 0.806
# Img : 0033_19.png True Label : character07  Predicted Label : character07 Accuracy : 0.813
# Img : 0033_17.png True Label : character07  Predicted Label : character07 Accuracy : 0.818
# Img : 0033_16.png True Label : character07  Predicted Label : character07 Accuracy : 0.824
# Img : 0033_18.png True Label : character07  Predicted Label : character07 Accuracy : 0.829
# Img : 0034_19.png True Label : character08  Predicted Label : character08 Accuracy : 0.833
# Img : 0034_20.png True Label : character08  Predicted Label : character08 Accuracy : 0.838
# Img : 0034_17.png True Label : character08  Predicted Label : character04 Accuracy : 0.816
# Img : 0034_18.png True Label : character08  Predicted Label : character11 Accuracy : 0.795
# Img : 0034_16.png True Label : character08  Predicted Label : character08 Accuracy : 0.8
# Img : 0035_17.png True Label : character09  Predicted Label : character09 Accuracy : 0.805
# Img : 0035_20.png True Label : character09  Predicted Label : character09 Accuracy : 0.81
# Img : 0035_19.png True Label : character09  Predicted Label : character09 Accuracy : 0.814
# Img : 0035_16.png True Label : character09  Predicted Label : character09 Accuracy : 0.818
# Img : 0035_18.png True Label : character09  Predicted Label : character09 Accuracy : 0.822
# Img : 0036_19.png True Label : character10  Predicted Label : character10 Accuracy : 0.826
# Img : 0036_17.png True Label : character10  Predicted Label : character10 Accuracy : 0.83
# Img : 0036_16.png True Label : character10  Predicted Label : character10 Accuracy : 0.833
# Img : 0036_20.png True Label : character10  Predicted Label : character10 Accuracy : 0.837
# Img : 0036_18.png True Label : character10  Predicted Label : character14 Accuracy : 0.82
# Img : 0037_19.png True Label : character11  Predicted Label : character11 Accuracy : 0.824
# Img : 0037_20.png True Label : character11  Predicted Label : character05 Accuracy : 0.808
# Img : 0037_17.png True Label : character11  Predicted Label : character11 Accuracy : 0.811
# Img : 0037_16.png True Label : character11  Predicted Label : character11 Accuracy : 0.815
# Img : 0037_18.png True Label : character11  Predicted Label : character16 Accuracy : 0.8
# Img : 0038_18.png True Label : character12  Predicted Label : character12 Accuracy : 0.804
# Img : 0038_16.png True Label : character12  Predicted Label : character12 Accuracy : 0.807
# Img : 0038_20.png True Label : character12  Predicted Label : character12 Accuracy : 0.81
# Img : 0038_17.png True Label : character12  Predicted Label : character12 Accuracy : 0.814
# Img : 0038_19.png True Label : character12  Predicted Label : character12 Accuracy : 0.817
# Img : 0039_17.png True Label : character13  Predicted Label : character13 Accuracy : 0.82
# Img : 0039_18.png True Label : character13  Predicted Label : character13 Accuracy : 0.823
# Img : 0039_19.png True Label : character13  Predicted Label : character13 Accuracy : 0.825
# Img : 0039_16.png True Label : character13  Predicted Label : character13 Accuracy : 0.828
# Img : 0039_20.png True Label : character13  Predicted Label : character13 Accuracy : 0.831
# Img : 0040_20.png True Label : character14  Predicted Label : character14 Accuracy : 0.833
# Img : 0040_16.png True Label : character14  Predicted Label : character05 Accuracy : 0.821
# Img : 0040_18.png True Label : character14  Predicted Label : character14 Accuracy : 0.824
# Img : 0040_17.png True Label : character14  Predicted Label : character14 Accuracy : 0.826
# Img : 0040_19.png True Label : character14  Predicted Label : character14 Accuracy : 0.829
# Img : 0041_17.png True Label : character15  Predicted Label : character16 Accuracy : 0.817
# Img : 0041_20.png True Label : character15  Predicted Label : character15 Accuracy : 0.819
# Img : 0041_16.png True Label : character15  Predicted Label : character15 Accuracy : 0.822
# Img : 0041_19.png True Label : character15  Predicted Label : character16 Accuracy : 0.811
# Img : 0041_18.png True Label : character15  Predicted Label : character15 Accuracy : 0.813
# Img : 0042_18.png True Label : character16  Predicted Label : character16 Accuracy : 0.816
# Img : 0042_17.png True Label : character16  Predicted Label : character05 Accuracy : 0.805
# Img : 0042_16.png True Label : character16  Predicted Label : character05 Accuracy : 0.795
# Img : 0042_20.png True Label : character16  Predicted Label : character16 Accuracy : 0.797
# Img : 0042_19.png True Label : character16  Predicted Label : character16 Accuracy : 0.8
# Img : 0043_18.png True Label : character17  Predicted Label : character17 Accuracy : 0.802
# Img : 0043_17.png True Label : character17  Predicted Label : character17 Accuracy : 0.805
# Img : 0043_19.png True Label : character17  Predicted Label : character17 Accuracy : 0.807
# Img : 0043_20.png True Label : character17  Predicted Label : character17 Accuracy : 0.81
# Img : 0043_16.png True Label : character17  Predicted Label : character17 Accuracy : 0.812
# Img : 0044_20.png True Label : character18  Predicted Label : character04 Accuracy : 0.802
# Img : 0044_17.png True Label : character18  Predicted Label : character04 Accuracy : 0.793
# Img : 0044_16.png True Label : character18  Predicted Label : character18 Accuracy : 0.795
# Img : 0044_19.png True Label : character18  Predicted Label : character04 Accuracy : 0.787
# Img : 0044_18.png True Label : character18  Predicted Label : character18 Accuracy : 0.789
# Img : 0045_18.png True Label : character19  Predicted Label : character19 Accuracy : 0.791
# Img : 0045_17.png True Label : character19  Predicted Label : character19 Accuracy : 0.793
# Img : 0045_20.png True Label : character19  Predicted Label : character19 Accuracy : 0.796
# Img : 0045_16.png True Label : character19  Predicted Label : character19 Accuracy : 0.798
# Img : 0045_19.png True Label : character19  Predicted Label : character19 Accuracy : 0.8
# Img : 0046_18.png True Label : character20  Predicted Label : character20 Accuracy : 0.802
# Img : 0046_17.png True Label : character20  Predicted Label : character20 Accuracy : 0.804
# Img : 0046_20.png True Label : character20  Predicted Label : character20 Accuracy : 0.806
# Img : 0046_16.png True Label : character20  Predicted Label : character20 Accuracy : 0.808
# Img : 0046_19.png True Label : character20  Predicted Label : character20 Accuracy : 0.81
# Accuracy : 0.81

# %%
save_model(model,'./bestModel_0.81.hdf5')

# %% [markdown]
# #### Accuracy on Train Data

# %%
os.chdir(trainPath)
folderList = os.listdir("./")

correctPred = 0
testImageCount = 0

for folder in folderList:
    os.chdir(os.path.join(trainPath,folder))
    imgList = os.listdir("./")
    
    for img in imgList:
        imgName = img
        testImageCount+=1
        supportImg = getSupportImgs(trainPath)
        
        img = read_img(os.path.join(trainPath,folder,img), imgSize)
        bestLabel = predictBest(img,folder,supportImg,model)
        
        if bestLabel == folder:
            correctPred+=1
        print("Img : {} True Label : {}  Predicted Label : {}".format(imgName,folder,bestLabel))
        
accuracy = correctPred/float(testImageCount)
print("Accuracy : {}".format(accuracy))
# Out:
# Img : 0871_10.png True Label : character21  Predicted Label : character09
# Img : 0871_01.png True Label : character21  Predicted Label : character09
# Img : 0871_04.png True Label : character21  Predicted Label : character09
# Img : 0871_07.png True Label : character21  Predicted Label : character09
# Img : 0871_03.png True Label : character21  Predicted Label : character09
# Img : 0871_13.png True Label : character21  Predicted Label : character09
# Img : 0871_06.png True Label : character21  Predicted Label : character09
# Img : 0871_05.png True Label : character21  Predicted Label : character09
# Img : 0871_15.png True Label : character21  Predicted Label : character09
# Img : 0871_02.png True Label : character21  Predicted Label : character09
# Img : 0871_09.png True Label : character21  Predicted Label : character09
# Img : 0871_11.png True Label : character21  Predicted Label : character09
# Img : 0871_08.png True Label : character21  Predicted Label : character09
# Img : 0871_14.png True Label : character21  Predicted Label : character09
# Img : 0871_12.png True Label : character21  Predicted Label : character09
# Img : 0873_07.png True Label : character23  Predicted Label : character19
# Img : 0873_04.png True Label : character23  Predicted Label : character19
# Img : 0873_03.png True Label : character23  Predicted Label : character19
# Img : 0873_06.png True Label : character23  Predicted Label : character19
# Img : 0873_14.png True Label : character23  Predicted Label : character19
# Img : 0873_15.png True Label : character23  Predicted Label : character19
# Img : 0873_11.png True Label : character23  Predicted Label : character19
# Img : 0873_12.png True Label : character23  Predicted Label : character19
# Img : 0873_01.png True Label : character23  Predicted Label : character19
# Img : 0873_09.png True Label : character23  Predicted Label : character19
# Img : 0873_08.png True Label : character23  Predicted Label : character19
# Img : 0873_05.png True Label : character23  Predicted Label : character19
# Img : 0873_13.png True Label : character23  Predicted Label : character19
# Img : 0873_02.png True Label : character23  Predicted Label : character19
# Img : 0873_10.png True Label : character23  Predicted Label : character19
# Img : 0856_07.png True Label : character06  Predicted Label : character09
# Img : 0856_14.png True Label : character06  Predicted Label : character09
# Img : 0856_10.png True Label : character06  Predicted Label : character09
# Img : 0856_12.png True Label : character06  Predicted Label : character09
# Img : 0856_13.png True Label : character06  Predicted Label : character09
# Img : 0856_02.png True Label : character06  Predicted Label : character09
# Img : 0856_01.png True Label : character06  Predicted Label : character09
# Img : 0856_04.png True Label : character06  Predicted Label : character09
# Img : 0856_11.png True Label : character06  Predicted Label : character09
# Img : 0856_08.png True Label : character06  Predicted Label : character09
# Img : 0856_05.png True Label : character06  Predicted Label : character09
# Img : 0856_03.png True Label : character06  Predicted Label : character09
# Img : 0856_06.png True Label : character06  Predicted Label : character09
# Img : 0856_09.png True Label : character06  Predicted Label : character09
# Img : 0856_15.png True Label : character06  Predicted Label : character09
# Img : 0864_14.png True Label : character14  Predicted Label : character19
# Img : 0864_05.png True Label : character14  Predicted Label : character19
# Img : 0864_15.png True Label : character14  Predicted Label : character19
# Img : 0864_10.png True Label : character14  Predicted Label : character19
# Img : 0864_06.png True Label : character14  Predicted Label : character19
# Img : 0864_09.png True Label : character14  Predicted Label : character19
# Img : 0864_03.png True Label : character14  Predicted Label : character19
# Img : 0864_01.png True Label : character14  Predicted Label : character19
# Img : 0864_04.png True Label : character14  Predicted Label : character19
# Img : 0864_07.png True Label : character14  Predicted Label : character19
# Img : 0864_11.png True Label : character14  Predicted Label : character19
# Img : 0864_13.png True Label : character14  Predicted Label : character19
# Img : 0864_08.png True Label : character14  Predicted Label : character19
# Img : 0864_02.png True Label : character14  Predicted Label : character19
# Img : 0864_12.png True Label : character14  Predicted Label : character19
# Img : 0858_04.png True Label : character08  Predicted Label : character11
# Img : 0858_07.png True Label : character08  Predicted Label : character19
# Img : 0858_01.png True Label : character08  Predicted Label : character11
# Img : 0858_15.png True Label : character08  Predicted Label : character11
# Img : 0858_08.png True Label : character08  Predicted Label : character11
# Img : 0858_13.png True Label : character08  Predicted Label : character11
# Img : 0858_11.png True Label : character08  Predicted Label : character11
# Img : 0858_02.png True Label : character08  Predicted Label : character11
# Img : 0858_06.png True Label : character08  Predicted Label : character11
# Img : 0858_03.png True Label : character08  Predicted Label : character11
# Img : 0858_14.png True Label : character08  Predicted Label : character11
# Img : 0858_05.png True Label : character08  Predicted Label : character11
# Img : 0858_10.png True Label : character08  Predicted Label : character11
# Img : 0858_09.png True Label : character08  Predicted Label : character11
# Img : 0858_12.png True Label : character08  Predicted Label : character11
# Img : 0853_06.png True Label : character03  Predicted Label : character05
# Img : 0853_14.png True Label : character03  Predicted Label : character05
# Img : 0853_02.png True Label : character03  Predicted Label : character05
# Img : 0853_08.png True Label : character03  Predicted Label : character05
# Img : 0853_09.png True Label : character03  Predicted Label : character05
# Img : 0853_01.png True Label : character03  Predicted Label : character05
# Img : 0853_04.png True Label : character03  Predicted Label : character05
# Img : 0853_11.png True Label : character03  Predicted Label : character05
# Img : 0853_13.png True Label : character03  Predicted Label : character05
# Img : 0853_07.png True Label : character03  Predicted Label : character05
# Img : 0853_05.png True Label : character03  Predicted Label : character05
# Img : 0853_12.png True Label : character03  Predicted Label : character05
# Img : 0853_10.png True Label : character03  Predicted Label : character05
# Img : 0853_15.png True Label : character03  Predicted Label : character05
# Img : 0853_03.png True Label : character03  Predicted Label : character05
# Img : 0878_08.png True Label : character28  Predicted Label : character19
# Img : 0878_12.png True Label : character28  Predicted Label : character21
# Img : 0878_01.png True Label : character28  Predicted Label : character19
# Img : 0878_02.png True Label : character28  Predicted Label : character19
# Img : 0878_06.png True Label : character28  Predicted Label : character19
# Img : 0878_05.png True Label : character28  Predicted Label : character21
# Img : 0878_14.png True Label : character28  Predicted Label : character21
# Img : 0878_11.png True Label : character28  Predicted Label : character19
# Img : 0878_04.png True Label : character28  Predicted Label : character19
# Img : 0878_09.png True Label : character28  Predicted Label : character19
# Img : 0878_07.png True Label : character28  Predicted Label : character19
# Img : 0878_03.png True Label : character28  Predicted Label : character19
# Img : 0878_13.png True Label : character28  Predicted Label : character21
# Img : 0878_15.png True Label : character28  Predicted Label : character19
# Img : 0878_10.png True Label : character28  Predicted Label : character19
# Img : 0854_11.png True Label : character04  Predicted Label : character11
# Img : 0854_02.png True Label : character04  Predicted Label : character11
# Img : 0854_07.png True Label : character04  Predicted Label : character11
# Img : 0854_13.png True Label : character04  Predicted Label : character11
# Img : 0854_09.png True Label : character04  Predicted Label : character11
# Img : 0854_01.png True Label : character04  Predicted Label : character11
# Img : 0854_10.png True Label : character04  Predicted Label : character11
# Img : 0854_14.png True Label : character04  Predicted Label : character11
# Img : 0854_05.png True Label : character04  Predicted Label : character11
# Img : 0854_15.png True Label : character04  Predicted Label : character11
# Img : 0854_12.png True Label : character04  Predicted Label : character11
# Img : 0854_06.png True Label : character04  Predicted Label : character11
# Img : 0854_08.png True Label : character04  Predicted Label : character11
# Img : 0854_03.png True Label : character04  Predicted Label : character11
# Img : 0854_04.png True Label : character04  Predicted Label : character11
# Img : 0862_12.png True Label : character12  Predicted Label : character19
# Img : 0862_07.png True Label : character12  Predicted Label : character19
# Img : 0862_02.png True Label : character12  Predicted Label : character19
# Img : 0862_04.png True Label : character12  Predicted Label : character19
# Img : 0862_05.png True Label : character12  Predicted Label : character19
# Img : 0862_09.png True Label : character12  Predicted Label : character19
# Img : 0862_13.png True Label : character12  Predicted Label : character19
# Img : 0862_15.png True Label : character12  Predicted Label : character19
# Img : 0862_11.png True Label : character12  Predicted Label : character19
# Img : 0862_14.png True Label : character12  Predicted Label : character19
# Img : 0862_06.png True Label : character12  Predicted Label : character19
# Img : 0862_03.png True Label : character12  Predicted Label : character19
# Img : 0862_01.png True Label : character12  Predicted Label : character19
# Img : 0862_10.png True Label : character12  Predicted Label : character19
# Img : 0862_08.png True Label : character12  Predicted Label : character19
# Img : 0875_02.png True Label : character25  Predicted Label : character11
# Img : 0875_11.png True Label : character25  Predicted Label : character11
# Img : 0875_07.png True Label : character25  Predicted Label : character11
# Img : 0875_04.png True Label : character25  Predicted Label : character11
# Img : 0875_03.png True Label : character25  Predicted Label : character11
# Img : 0875_01.png True Label : character25  Predicted Label : character11
# Img : 0875_08.png True Label : character25  Predicted Label : character11
# Img : 0875_13.png True Label : character25  Predicted Label : character11
# Img : 0875_12.png True Label : character25  Predicted Label : character11
# Img : 0875_10.png True Label : character25  Predicted Label : character11
# Img : 0875_15.png True Label : character25  Predicted Label : character11
# Img : 0875_06.png True Label : character25  Predicted Label : character11
# Img : 0875_05.png True Label : character25  Predicted Label : character11
# Img : 0875_09.png True Label : character25  Predicted Label : character11
# Img : 0875_14.png True Label : character25  Predicted Label : character11
# Img : 0876_03.png True Label : character26  Predicted Label : character11
# Img : 0876_07.png True Label : character26  Predicted Label : character11
# Img : 0876_01.png True Label : character26  Predicted Label : character11
# Img : 0876_05.png True Label : character26  Predicted Label : character11
# Img : 0876_14.png True Label : character26  Predicted Label : character11
# Img : 0876_10.png True Label : character26  Predicted Label : character11
# Img : 0876_13.png True Label : character26  Predicted Label : character11
# Img : 0876_09.png True Label : character26  Predicted Label : character11
# Img : 0876_15.png True Label : character26  Predicted Label : character11
# Img : 0876_06.png True Label : character26  Predicted Label : character11
# Img : 0876_08.png True Label : character26  Predicted Label : character11
# Img : 0876_11.png True Label : character26  Predicted Label : character11
# Img : 0876_04.png True Label : character26  Predicted Label : character11
# Img : 0876_02.png True Label : character26  Predicted Label : character11
# Img : 0876_12.png True Label : character26  Predicted Label : character11
# Img : 0872_08.png True Label : character22  Predicted Label : character11
# Img : 0872_01.png True Label : character22  Predicted Label : character11
# Img : 0872_12.png True Label : character22  Predicted Label : character11
# Img : 0872_14.png True Label : character22  Predicted Label : character11
# Img : 0872_11.png True Label : character22  Predicted Label : character11
# Img : 0872_13.png True Label : character22  Predicted Label : character11
# Img : 0872_06.png True Label : character22  Predicted Label : character11
# Img : 0872_04.png True Label : character22  Predicted Label : character11
# Img : 0872_15.png True Label : character22  Predicted Label : character11
# Img : 0872_05.png True Label : character22  Predicted Label : character11
# Img : 0872_09.png True Label : character22  Predicted Label : character11
# Img : 0872_02.png True Label : character22  Predicted Label : character11
# Img : 0872_10.png True Label : character22  Predicted Label : character11
# Img : 0872_07.png True Label : character22  Predicted Label : character11
# Img : 0872_03.png True Label : character22  Predicted Label : character11
# Img : 0863_02.png True Label : character13  Predicted Label : character19
# Img : 0863_07.png True Label : character13  Predicted Label : character19
# Img : 0863_13.png True Label : character13  Predicted Label : character19
# Img : 0863_11.png True Label : character13  Predicted Label : character19
# Img : 0863_04.png True Label : character13  Predicted Label : character19
# Img : 0863_14.png True Label : character13  Predicted Label : character19
# Img : 0863_10.png True Label : character13  Predicted Label : character19
# Img : 0863_05.png True Label : character13  Predicted Label : character19
# Img : 0863_15.png True Label : character13  Predicted Label : character19
# Img : 0863_01.png True Label : character13  Predicted Label : character19
# Img : 0863_12.png True Label : character13  Predicted Label : character19
# Img : 0863_08.png True Label : character13  Predicted Label : character19
# Img : 0863_03.png True Label : character13  Predicted Label : character19
# Img : 0863_06.png True Label : character13  Predicted Label : character19
# Img : 0863_09.png True Label : character13  Predicted Label : character19
# Img : 0866_04.png True Label : character16  Predicted Label : character19
# Img : 0866_10.png True Label : character16  Predicted Label : character19
# Img : 0866_03.png True Label : character16  Predicted Label : character19
# Img : 0866_01.png True Label : character16  Predicted Label : character19
# Img : 0866_14.png True Label : character16  Predicted Label : character19
# Img : 0866_08.png True Label : character16  Predicted Label : character19
# Img : 0866_07.png True Label : character16  Predicted Label : character19
# Img : 0866_15.png True Label : character16  Predicted Label : character19
# Img : 0866_12.png True Label : character16  Predicted Label : character19
# Img : 0866_09.png True Label : character16  Predicted Label : character19
# Img : 0866_02.png True Label : character16  Predicted Label : character19
# Img : 0866_13.png True Label : character16  Predicted Label : character19
# Img : 0866_11.png True Label : character16  Predicted Label : character19
# Img : 0866_05.png True Label : character16  Predicted Label : character19
# Img : 0866_06.png True Label : character16  Predicted Label : character19
# Img : 0877_02.png True Label : character27  Predicted Label : character19
# Img : 0877_07.png True Label : character27  Predicted Label : character19
# Img : 0877_04.png True Label : character27  Predicted Label : character19
# Img : 0877_08.png True Label : character27  Predicted Label : character19
# Img : 0877_03.png True Label : character27  Predicted Label : character19
# Img : 0877_10.png True Label : character27  Predicted Label : character19
# Img : 0877_06.png True Label : character27  Predicted Label : character19
# Img : 0877_05.png True Label : character27  Predicted Label : character19
# Img : 0877_15.png True Label : character27  Predicted Label : character19
# Img : 0877_11.png True Label : character27  Predicted Label : character19
# Img : 0877_01.png True Label : character27  Predicted Label : character19
# Img : 0877_12.png True Label : character27  Predicted Label : character19
# Img : 0877_13.png True Label : character27  Predicted Label : character19
# Img : 0877_09.png True Label : character27  Predicted Label : character19
# Img : 0877_14.png True Label : character27  Predicted Label : character19
# Img : 0865_10.png True Label : character15  Predicted Label : character14
# Img : 0865_12.png True Label : character15  Predicted Label : character11
# Img : 0865_04.png True Label : character15  Predicted Label : character11
# Img : 0865_11.png True Label : character15  Predicted Label : character11
# Img : 0865_08.png True Label : character15  Predicted Label : character11
# Img : 0865_09.png True Label : character15  Predicted Label : character14
# Img : 0865_15.png True Label : character15  Predicted Label : character11
# Img : 0865_03.png True Label : character15  Predicted Label : character11
# Img : 0865_05.png True Label : character15  Predicted Label : character11
# Img : 0865_07.png True Label : character15  Predicted Label : character11
# Img : 0865_02.png True Label : character15  Predicted Label : character11
# Img : 0865_06.png True Label : character15  Predicted Label : character11
# Img : 0865_14.png True Label : character15  Predicted Label : character11
# Img : 0865_01.png True Label : character15  Predicted Label : character11
# Img : 0865_13.png True Label : character15  Predicted Label : character11
# Img : 0870_01.png True Label : character20  Predicted Label : character19
# Img : 0870_15.png True Label : character20  Predicted Label : character19
# Img : 0870_05.png True Label : character20  Predicted Label : character19
# Img : 0870_11.png True Label : character20  Predicted Label : character19
# Img : 0870_08.png True Label : character20  Predicted Label : character19
# Img : 0870_06.png True Label : character20  Predicted Label : character19
# Img : 0870_03.png True Label : character20  Predicted Label : character19
# Img : 0870_09.png True Label : character20  Predicted Label : character19
# Img : 0870_12.png True Label : character20  Predicted Label : character19
# Img : 0870_13.png True Label : character20  Predicted Label : character19
# Img : 0870_10.png True Label : character20  Predicted Label : character19
# Img : 0870_07.png True Label : character20  Predicted Label : character19
# Img : 0870_14.png True Label : character20  Predicted Label : character19
# Img : 0870_04.png True Label : character20  Predicted Label : character19
# Img : 0870_02.png True Label : character20  Predicted Label : character19
# Img : 0868_14.png True Label : character18  Predicted Label : character19
# Img : 0868_08.png True Label : character18  Predicted Label : character19
# Img : 0868_01.png True Label : character18  Predicted Label : character19
# Img : 0868_10.png True Label : character18  Predicted Label : character19
# Img : 0868_13.png True Label : character18  Predicted Label : character19
# Img : 0868_04.png True Label : character18  Predicted Label : character19
# Img : 0868_03.png True Label : character18  Predicted Label : character19
# Img : 0868_12.png True Label : character18  Predicted Label : character19
# Img : 0868_06.png True Label : character18  Predicted Label : character19
# Img : 0868_05.png True Label : character18  Predicted Label : character19
# Img : 0868_15.png True Label : character18  Predicted Label : character19
# Img : 0868_11.png True Label : character18  Predicted Label : character19
# Img : 0868_09.png True Label : character18  Predicted Label : character19
# Img : 0868_07.png True Label : character18  Predicted Label : character19
# Img : 0868_02.png True Label : character18  Predicted Label : character19
# Img : 0867_06.png True Label : character17  Predicted Label : character11
# Img : 0867_15.png True Label : character17  Predicted Label : character11
# Img : 0867_11.png True Label : character17  Predicted Label : character11
# Img : 0867_08.png True Label : character17  Predicted Label : character11
# Img : 0867_12.png True Label : character17  Predicted Label : character11
# Img : 0867_04.png True Label : character17  Predicted Label : character11
# Img : 0867_05.png True Label : character17  Predicted Label : character11
# Img : 0867_07.png True Label : character17  Predicted Label : character11
# Img : 0867_10.png True Label : character17  Predicted Label : character11
# Img : 0867_01.png True Label : character17  Predicted Label : character11
# Img : 0867_02.png True Label : character17  Predicted Label : character11
# Img : 0867_13.png True Label : character17  Predicted Label : character11
# Img : 0867_14.png True Label : character17  Predicted Label : character11
# Img : 0867_03.png True Label : character17  Predicted Label : character11
# Img : 0867_09.png True Label : character17  Predicted Label : character11
# Img : 0874_03.png True Label : character24  Predicted Label : character11
# Img : 0874_10.png True Label : character24  Predicted Label : character11
# Img : 0874_11.png True Label : character24  Predicted Label : character11
# Img : 0874_14.png True Label : character24  Predicted Label : character11
# Img : 0874_12.png True Label : character24  Predicted Label : character11
# Img : 0874_08.png True Label : character24  Predicted Label : character11
# Img : 0874_13.png True Label : character24  Predicted Label : character11
# Img : 0874_01.png True Label : character24  Predicted Label : character11
# Img : 0874_05.png True Label : character24  Predicted Label : character11
# Img : 0874_02.png True Label : character24  Predicted Label : character11
# Img : 0874_15.png True Label : character24  Predicted Label : character11
# Img : 0874_09.png True Label : character24  Predicted Label : character11
# Img : 0874_04.png True Label : character24  Predicted Label : character11
# Img : 0874_06.png True Label : character24  Predicted Label : character11
# Img : 0874_07.png True Label : character24  Predicted Label : character11
# Img : 0857_14.png True Label : character07  Predicted Label : character03
# Img : 0857_05.png True Label : character07  Predicted Label : character27
# Img : 0857_02.png True Label : character07  Predicted Label : character03
# Img : 0857_10.png True Label : character07  Predicted Label : character27
# Img : 0857_11.png True Label : character07  Predicted Label : character03
# Img : 0857_08.png True Label : character07  Predicted Label : character03
# Img : 0857_15.png True Label : character07  Predicted Label : character03
# Img : 0857_03.png True Label : character07  Predicted Label : character03
# Img : 0857_01.png True Label : character07  Predicted Label : character03
# Img : 0857_12.png True Label : character07  Predicted Label : character03
# Img : 0857_13.png True Label : character07  Predicted Label : character03
# Img : 0857_07.png True Label : character07  Predicted Label : character03
# Img : 0857_04.png True Label : character07  Predicted Label : character03
# Img : 0857_06.png True Label : character07  Predicted Label : character03
# Img : 0857_09.png True Label : character07  Predicted Label : character03
# Img : 0860_15.png True Label : character10  Predicted Label : character14
# Img : 0860_12.png True Label : character10  Predicted Label : character14
# Img : 0860_05.png True Label : character10  Predicted Label : character14
# Img : 0860_07.png True Label : character10  Predicted Label : character14
# Img : 0860_08.png True Label : character10  Predicted Label : character14
# Img : 0860_01.png True Label : character10  Predicted Label : character14
# Img : 0860_10.png True Label : character10  Predicted Label : character14
# Img : 0860_09.png True Label : character10  Predicted Label : character14
# Img : 0860_04.png True Label : character10  Predicted Label : character14
# Img : 0860_03.png True Label : character10  Predicted Label : character14
# Img : 0860_14.png True Label : character10  Predicted Label : character19
# Img : 0860_11.png True Label : character10  Predicted Label : character14
# Img : 0860_02.png True Label : character10  Predicted Label : character14
# Img : 0860_06.png True Label : character10  Predicted Label : character11
# Img : 0860_13.png True Label : character10  Predicted Label : character14
# Img : 0861_07.png True Label : character11  Predicted Label : character19
# Img : 0861_14.png True Label : character11  Predicted Label : character19
# Img : 0861_01.png True Label : character11  Predicted Label : character19
# Img : 0861_12.png True Label : character11  Predicted Label : character19
# Img : 0861_03.png True Label : character11  Predicted Label : character19
# Img : 0861_13.png True Label : character11  Predicted Label : character19
# Img : 0861_02.png True Label : character11  Predicted Label : character19
# Img : 0861_10.png True Label : character11  Predicted Label : character19
# Img : 0861_05.png True Label : character11  Predicted Label : character19
# Img : 0861_11.png True Label : character11  Predicted Label : character19
# Img : 0861_09.png True Label : character11  Predicted Label : character19
# Img : 0861_04.png True Label : character11  Predicted Label : character19
# Img : 0861_08.png True Label : character11  Predicted Label : character19
# Img : 0861_15.png True Label : character11  Predicted Label : character19
# Img : 0861_06.png True Label : character11  Predicted Label : character19
# Img : 0851_11.png True Label : character01  Predicted Label : character11
# Img : 0851_12.png True Label : character01  Predicted Label : character11
# Img : 0851_05.png True Label : character01  Predicted Label : character11
# Img : 0851_06.png True Label : character01  Predicted Label : character11
# Img : 0851_07.png True Label : character01  Predicted Label : character11
# Img : 0851_14.png True Label : character01  Predicted Label : character11
# Img : 0851_08.png True Label : character01  Predicted Label : character11
# Img : 0851_03.png True Label : character01  Predicted Label : character11
# Img : 0851_13.png True Label : character01  Predicted Label : character11
# Img : 0851_15.png True Label : character01  Predicted Label : character11
# Img : 0851_09.png True Label : character01  Predicted Label : character11
# Img : 0851_02.png True Label : character01  Predicted Label : character11
# Img : 0851_04.png True Label : character01  Predicted Label : character11
# Img : 0851_01.png True Label : character01  Predicted Label : character11
# Img : 0851_10.png True Label : character01  Predicted Label : character11
# Img : 0859_01.png True Label : character09  Predicted Label : character27
# Img : 0859_10.png True Label : character09  Predicted Label : character27
# Img : 0859_04.png True Label : character09  Predicted Label : character27
# Img : 0859_05.png True Label : character09  Predicted Label : character27
# Img : 0859_07.png True Label : character09  Predicted Label : character27
# Img : 0859_02.png True Label : character09  Predicted Label : character27
# Img : 0859_03.png True Label : character09  Predicted Label : character27
# Img : 0859_06.png True Label : character09  Predicted Label : character27
# Img : 0859_08.png True Label : character09  Predicted Label : character27
# Img : 0859_14.png True Label : character09  Predicted Label : character27
# Img : 0859_12.png True Label : character09  Predicted Label : character27
# Img : 0859_11.png True Label : character09  Predicted Label : character27
# Img : 0859_09.png True Label : character09  Predicted Label : character27
# Img : 0859_15.png True Label : character09  Predicted Label : character27
# Img : 0859_13.png True Label : character09  Predicted Label : character27
# Img : 0880_07.png True Label : character30  Predicted Label : character11
# Img : 0880_02.png True Label : character30  Predicted Label : character11
# Img : 0880_08.png True Label : character30  Predicted Label : character11
# Img : 0880_06.png True Label : character30  Predicted Label : character11
# Img : 0880_13.png True Label : character30  Predicted Label : character11
# Img : 0880_11.png True Label : character30  Predicted Label : character11
# Img : 0880_01.png True Label : character30  Predicted Label : character11
# Img : 0880_09.png True Label : character30  Predicted Label : character11
# Img : 0880_05.png True Label : character30  Predicted Label : character11
# Img : 0880_04.png True Label : character30  Predicted Label : character11
# Img : 0880_14.png True Label : character30  Predicted Label : character11
# Img : 0880_03.png True Label : character30  Predicted Label : character11
# Img : 0880_12.png True Label : character30  Predicted Label : character11
# Img : 0880_15.png True Label : character30  Predicted Label : character11
# Img : 0880_10.png True Label : character30  Predicted Label : character11
# Img : 0852_11.png True Label : character02  Predicted Label : character11
# Img : 0852_04.png True Label : character02  Predicted Label : character11
# Img : 0852_05.png True Label : character02  Predicted Label : character11
# Img : 0852_09.png True Label : character02  Predicted Label : character11
# Img : 0852_03.png True Label : character02  Predicted Label : character11
# Img : 0852_13.png True Label : character02  Predicted Label : character11
# Img : 0852_06.png True Label : character02  Predicted Label : character11
# Img : 0852_07.png True Label : character02  Predicted Label : character11
# Img : 0852_10.png True Label : character02  Predicted Label : character11
# Img : 0852_14.png True Label : character02  Predicted Label : character11
# Img : 0852_08.png True Label : character02  Predicted Label : character11
# Img : 0852_15.png True Label : character02  Predicted Label : character11
# Img : 0852_01.png True Label : character02  Predicted Label : character11
# Img : 0852_02.png True Label : character02  Predicted Label : character11
# Img : 0852_12.png True Label : character02  Predicted Label : character11
# Img : 0869_09.png True Label : character19  Predicted Label : character11
# Img : 0869_13.png True Label : character19  Predicted Label : character11
# Img : 0869_14.png True Label : character19  Predicted Label : character11
# Img : 0869_03.png True Label : character19  Predicted Label : character11
# Img : 0869_01.png True Label : character19  Predicted Label : character11
# Img : 0869_04.png True Label : character19  Predicted Label : character11
# Img : 0869_12.png True Label : character19  Predicted Label : character11
# Img : 0869_11.png True Label : character19  Predicted Label : character11
# Img : 0869_08.png True Label : character19  Predicted Label : character11
# Img : 0869_06.png True Label : character19  Predicted Label : character11
# Img : 0869_10.png True Label : character19  Predicted Label : character11
# Img : 0869_02.png True Label : character19  Predicted Label : character11
# Img : 0869_15.png True Label : character19  Predicted Label : character11
# Img : 0869_05.png True Label : character19  Predicted Label : character11
# Img : 0869_07.png True Label : character19  Predicted Label : character11
# Img : 0879_04.png True Label : character29  Predicted Label : character19
# Img : 0879_15.png True Label : character29  Predicted Label : character19
# Img : 0879_07.png True Label : character29  Predicted Label : character19
# Img : 0879_13.png True Label : character29  Predicted Label : character19
# Img : 0879_03.png True Label : character29  Predicted Label : character19
# Img : 0879_05.png True Label : character29  Predicted Label : character19
# Img : 0879_06.png True Label : character29  Predicted Label : character19
# Img : 0879_08.png True Label : character29  Predicted Label : character19
# Img : 0879_11.png True Label : character29  Predicted Label : character19
# Img : 0879_09.png True Label : character29  Predicted Label : character19
# Img : 0879_10.png True Label : character29  Predicted Label : character19
# Img : 0879_12.png True Label : character29  Predicted Label : character19
# Img : 0879_02.png True Label : character29  Predicted Label : character19
# Img : 0879_14.png True Label : character29  Predicted Label : character19
# Img : 0879_01.png True Label : character29  Predicted Label : character19
# Img : 0855_05.png True Label : character05  Predicted Label : character19
# Img : 0855_02.png True Label : character05  Predicted Label : character19
# Img : 0855_13.png True Label : character05  Predicted Label : character19
# Img : 0855_08.png True Label : character05  Predicted Label : character19
# Img : 0855_04.png True Label : character05  Predicted Label : character19
# Img : 0855_12.png True Label : character05  Predicted Label : character19
# Img : 0855_06.png True Label : character05  Predicted Label : character19
# Img : 0855_10.png True Label : character05  Predicted Label : character03
# Img : 0855_01.png True Label : character05  Predicted Label : character03
# Img : 0855_11.png True Label : character05  Predicted Label : character19
# Img : 0855_03.png True Label : character05  Predicted Label : character19
# Img : 0855_15.png True Label : character05  Predicted Label : character19
# Img : 0855_07.png True Label : character05  Predicted Label : character19
# Img : 0855_09.png True Label : character05  Predicted Label : character19
# Img : 0855_14.png True Label : character05  Predicted Label : character19
# Accuracy : 0.0

# %%
accuracy = correctPred/float(testImageCount)
print("Accuracy : {}".format(accuracy))
# Out:
# Accuracy : 0.377777777778

# %% [markdown]
# ### Accessory Functions
# ##### To evaluate the predictions

# %%
def getImage(folder,imgNo,train=True):
    
    if train==True:
        image = sorted(os.listdir(os.path.join(trainPath,folder)))[imgNo]
        image = read_img(os.path.join(trainPath,folder,image), imgSize)
    else:
        image = sorted(os.listdir(os.path.join(testPath,folder)))[imgNo]
        image = read_img(os.path.join(testPath,folder,image), imgSize)
        
    return(image)
        
    
a = getImage('character03',4,train = False)

# %%
predictBestFolder(a,'xxxx',trainPath,model,15,printList=True)
# Out:
# [['character18', 0.47063953], ['character03', 0.5668649], ['character06', 0.7414245], ['character04', 0.90950096], ['character24', 1.0128773], ['character30', 1.0532554], ['character26', 1.0919914], ['character15', 1.1090348], ['character22', 1.1398655], ['character08', 1.1790216], ['character19', 1.1845927], ['character27', 1.1921993], ['character17', 1.2045933], ['character20', 1.4039037], ['character29', 1.4283993], ['character07', 1.4514846], ['character02', 1.635681], ['character01', 1.6868922], ['character28', 1.7018459], ['character12', 1.713475], ['character14', 1.7223102], ['character05', 1.7527518], ['character13', 1.7751232], ['character10', 1.793034], ['character16', 1.8568423], ['character11', 1.8821567], ['character09', 1.9020066], ['character23', 1.9939858], ['character25', 2.1224973], ['character21', 2.1603959]]
# ['character18', 0.47063953]

# %%
def checkPred(folder1,img1,folder2,img2,train1=True,train2=True):
    
    if train1 == True:
        image1 = sorted(os.listdir(os.path.join(trainPath,folder1)))[img1]
        image1 = read_img(os.path.join(trainPath,folder1,image1), imgSize)
    else:
        image1 = sorted(os.listdir(os.path.join(testPath,folder1)))[img1]
        image1 = read_img(os.path.join(testPath,folder1,image1), imgSize)
        
    if train2 == True:
        image2 = sorted(os.listdir(os.path.join(trainPath,folder2)))[img2]
        image2 = read_img(os.path.join(trainPath,folder2,image2), imgSize)
    else:
        image2 = sorted(os.listdir(os.path.join(testPath,folder2)))[img2]
        print(image2)
        image2 = read_img(os.path.join(testPath,folder2,image2), imgSize)
        
    
    pred = model.predict([image1.reshape(1,45,45,3), image2.reshape(1,imgSize[0],imgSize[1],3)])
    
    plt.subplot(211)
    plt.imshow(image1)
    
    plt.subplot(212)
    plt.imshow(image2)
    
    print(pred)

# %%
checkPred('character02',5,'character02',2,train2= False)
# Out:
# 0028_18.png
# [[0.60623467]]
